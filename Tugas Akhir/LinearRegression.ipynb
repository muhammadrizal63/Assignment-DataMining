

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train[:, 3:] = sc.fit_transform(x_train[:, 3:])
x_test[:, 3:] = sc.transform(x_test[:, 3:])

# %%
x_train
# Out:
# array([[ 2.39000000e+02,  3.10000000e+02,  1.04000000e+02, ...,
#          9.33125166e-03, -3.26581756e-01, -1.11114215e+00],
#        [ 4.39000000e+02,  3.18000000e+02,  1.10000000e+02, ...,
#          9.33125166e-03, -4.59352324e-02,  8.99974861e-01],
#        [ 4.76000000e+02,  3.00000000e+02,  1.01000000e+02, ...,
#         -1.05709751e+00, -1.13550409e+00, -1.11114215e+00],
#        ...,
#        [ 3.97000000e+02,  3.25000000e+02,  1.07000000e+02, ...,
#          9.33125166e-03,  8.95056052e-01,  8.99974861e-01],
#        [ 2.36000000e+02,  3.26000000e+02,  1.11000000e+02, ...,
#          5.42545632e-01,  1.09315948e+00,  8.99974861e-01],
#        [ 3.80000000e+01,  3.00000000e+02,  1.05000000e+02, ...,
#         -1.59031189e+00, -1.26757304e+00, -1.11114215e+00]])

# %%
x_test
# Out:
# array([[ 3.05000000e+02,  3.13000000e+02,  1.06000000e+02,
#         -9.28809220e-01, -8.45045494e-01, -1.59031189e+00,
#         -2.27530042e-01, -1.11114215e+00],
#        [ 3.41000000e+02,  3.12000000e+02,  1.07000000e+02,
#         -5.46358365e-02, -3.52307597e-01, -5.23883129e-01,
#         -1.78004185e-01,  8.99974861e-01],
#        [ 4.80000000e+01,  3.39000000e+02,  1.19000000e+02,
#          1.69371093e+00,  1.12590610e+00,  5.42545632e-01,
#          1.86906457e+00, -1.11114215e+00],
#        [ 6.80000000e+01,  3.16000000e+02,  1.07000000e+02,
#         -9.28809220e-01,  1.40430301e-01,  9.33125166e-03,
#          1.19150958e-01,  8.99974861e-01],
#        [ 4.80000000e+02,  3.25000000e+02,  1.10000000e+02,
#          8.19537547e-01,  1.12590610e+00,  5.42545632e-01,
#          6.47426767e-01,  8.99974861e-01],
#        [ 4.86000000e+02,  3.11000000e+02,  1.01000000e+02,
#         -9.28809220e-01, -8.45045494e-01,  9.33125166e-03,
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
dataset = pd.read_csv('prediksis2.csv')
dataset
# Out:
#      Serial No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance_of_Admit
# ...

# %%
# %matplotlib inline
plt.xlabel('GRE Score')
plt.ylabel('CGPA')
plt.scatter(dataset.GRE_Score, dataset.CGPA)
plt.plot(dataset.GRE_Score,reg.predict(dataset[['GRE_Score']]),color='red')

# %%
reg = linear_model.LinearRegression()
reg.fit(dataset[['GRE_Score']],dataset.CGPA)
# Out:
# LinearRegression()

# %%
reg.predict([[340]])
# Out:
# D:\datamining\app\env\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.61691085])

# %%
reg.coef_
# Out:
# array([0.04422266])

# %%
reg.intercept_
# Out:
# -5.418795105597956
